# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import statsmodels.api as sm

df = pd.read_csv('/Users/cai/Downloads/CPS-Analytics/Quarter 3/ALY 6040/Group dataset/car data3.csv')

#read the game sales data csv file

# %%
df
# Out:
#        Year  Engine HP  Engine Cylinders  Number of Doors  Vehicle Size  \
# 0      2011        335                 6                2             1
# 1      2011        300                 6                2             1
# 2      2011        300                 6                2             1
# 3      2011        230                 6                2             1
# 4      2011        230                 6                2             1
# ...     ...        ...               ...              ...           ...
# 11909  2012        300                 6                4             2
# 11910  2012        300                 6                4             2
# 11911  2012        300                 6                4             2
# 11912  2013        300                 6                4             2
# 11913  2006        221                 6                4             2
#
#        highway MPG  city mpg  Popularity   MSRP  Trans_Reg
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['MSRP','Vehicle Size','Trans_Reg'], axis=1)
Y = df['MSRP']

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.2)

# %%
X2 = sm.add_constant(x_train) 
est = sm.OLS(y_train, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   MSRP   R-squared:                       0.453
# Model:                            OLS   Adj. R-squared:                  0.453
# Method:                 Least Squares   F-statistic:                     1128.
# Date:                Mon, 24 May 2021   Prob (F-statistic):               0.00
# Time:                        16:39:49   Log-Likelihood:            -1.1600e+05
# No. Observations:                9531   AIC:                         2.320e+05
# Df Residuals:                    9523   BIC:                         2.321e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -1.285e+05   1.74e+05     -0.740      0.459   -4.69e+05    2.12e+05
# ...

# %%
plt.figure(figsize=(10, 7))
df.corr().sort_values('MSRP').drop('MSRP')['MSRP'].plot(kind='bar', title='Variables correlation with MSRP')
# Out:
# <AxesSubplot:title={'center':'Variables correlation with MSRP'}>
